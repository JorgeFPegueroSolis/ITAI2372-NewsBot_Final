# %%
# !pip install spacy scikit-learn nltk pandas matplotlib seaborn wordcloud plotly langdetect deep-translator
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 15.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.8 MB/s eta 0:00:00
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=bca0fb97d010b90207ed3a4daa3d365c48ede076c1e79ce67b9aa71bd950c1f0
#   Stored in directory: /root/.cache/pip/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 57.3 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys

project_path = '/content/drive/MyDrive/ITAI2373-NEWSBT-MIDTERM'

sys.path.append(project_path)

# %%
from deep_translator import GoogleTranslator
from langdetect import detect


def language_detection(text):

  language = detect(text)

  return language


def translate(text, target_lang):

  translated = GoogleTranslator(source='auto', target=target_lang).translate(text)

  return translated

# %%
samples = ['Quiero comer carne.', 'I want to eat', '肉が食べたいです']


for sample in samples:
  print(language_detection(sample))
  print(translate(sample, 'en'))
# Out:
# it
# I want to eat meat.
# en
# I want to eat
# ja
# I want to eat meat

# %%
# %%writefile /content/drive/MyDrive/ITAI2373-NEWSBT-MIDTERM/newsbot/language_detection.py

from langdetect import detect

def language_detection(text):

  language = detect(text)

  return language
# Out:
# Writing /content/drive/MyDrive/ITAI2373-NEWSBT-MIDTERM/newsbot/language_detection.py

# %%
# %%writefile /content/drive/MyDrive/ITAI2373-NEWSBT-MIDTERM/newsbot/translation.py

from deep_translator import GoogleTranslator

def translate(text, target_lang):

  translated = GoogleTranslator(source='auto', target=target_lang).translate(text)

  return translated
# Out:
# Writing /content/drive/MyDrive/ITAI2373-NEWSBT-MIDTERM/newsbot/translation.py
